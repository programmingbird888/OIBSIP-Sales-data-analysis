# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn import svm

# %%
df = pd.read_csv('Advertising.CSV')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.Sales=df.Sales*1000000

# %%
for i in ['TV', 'Radio', 'Newspaper']:
    df[i] = df[i]*1000
df
# Out:
#            TV    Radio  Newspaper       Sales
# 0    230100.0  37800.0    69200.0  22100000.0
# 1     44500.0  39300.0    45100.0  10400000.0
# 2     17200.0  45900.0    69300.0   9300000.0
# 3    151500.0  41300.0    58500.0  18500000.0
# 4    180800.0  10800.0    58400.0  12900000.0
# ..        ...      ...        ...         ...
# 195   38200.0   3700.0    13800.0   7600000.0
# 196   94200.0   4900.0     8100.0   9700000.0
# 197  177000.0   9300.0     6400.0  12800000.0
# 198  283600.0  42000.0    66200.0  25500000.0
# 199  232100.0   8600.0     8700.0  13400000.0
#
# [200 rows x 4 columns]

# %%
df=df.astype({'Sales':int})

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(),annot=True,cmap = 'Blues')
# Out:
# <Axes: >

# %%
x = df[['TV','Radio','Newspaper']]
y = df[['Sales']]
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn import linear_model
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y = model.predict(X_test)
y
# Out:
# array([15000000, 19000000, 23800000,  7000000, 23200000, 14700000,
#        22600000,  9700000, 11700000, 15500000,  9500000,  8600000,
#        12700000,  1600000, 10300000, 11600000,  7000000, 17000000,
#        14600000, 20100000, 19400000, 14700000, 10800000, 24400000,
#         9900000,  8700000, 22600000, 11500000,  9700000,  3200000,
#        11400000, 10100000, 19200000,  9300000, 15700000, 20100000,
#        11800000, 24400000, 11500000,  7300000, 11600000, 11500000,
#        13600000,  9700000, 11400000,  9700000, 11400000, 14700000,
#        11000000, 11800000])
